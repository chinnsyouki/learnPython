# %%
import xalpha as xa
import pandas as pd

#投资标的
#新华纯债添利A 519152
#易方达沪深300ETF联接A 110020
#嘉实中证500ETF联接  000008
#博时标普500ETF联接A 050025
#大成纳斯达克100指数  000834

aim1 = xa.fundinfo('519152')
aim2 = xa.fundinfo('110020')
aim3 = xa.fundinfo('000008')
aim4 = xa.fundinfo('050025')
aim5 = xa.fundinfo('000834')

#每隔2周定投一次
#data_range = pd.date_range('2018-03-01','2020-03-07',freq='14D')

#每只基金都定投100
#dingtou1 = xa.policy.scheduled(aim1,100,data_range)
#dingtou2 = xa.policy.scheduled(aim2,100,data_range)
#dingtou3 = xa.policy.scheduled(aim3,100,data_range)
#dingtou4 = xa.policy.scheduled(aim4,100,data_range)
#dingtou5 = xa.policy.scheduled(aim5,100,data_range)

#每只基金都进行网格交易
dingtou1 = xa.policy.grid(aim1,[1,1,1,1,1],[4,4,4,4,4],'2018-03-01','2020-03-01',2000)
dingtou2 = xa.policy.grid(aim2,[1,1,1,1,1],[4,4,4,4,4],'2018-03-01','2020-03-01',2000)
dingtou3 = xa.policy.grid(aim3,[1,1,1,1,1],[4,4,4,4,4],'2018-03-01','2020-03-01',2000)
dingtou4 = xa.policy.grid(aim4,[1,1,1,1,1],[4,4,4,4,4],'2018-03-01','2020-03-01',2000)
dingtou5 = xa.policy.grid(aim5,[1,1,1,1,1],[4,4,4,4,4],'2018-03-01','2020-03-01',2000)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     354         else:
# --> 355             conn.request(method, url, **httplib_request_kw)
#     356
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     182     def connect(self):
# --> 183         conn = self._new_conn()
#     184         self._prepare_conn(conn)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e)
#     170
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x125930198>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     640             retries = retries.increment(method, url, error=e, _pool=self,
# --> 641                                         _stacktrace=sys.exc_info()[2])
#     642             retries.sleep()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPConnectionPool(host='fund.eastmoney.com', port=80): Max retries exceeded with url: /pingzhongdata/519152.js (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x125930198>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-13-f35edea1d6ad> in <module>
#       9 #大成纳斯达克100指数  000834
#      10
# ---> 11 aim1 = xa.fundinfo('519152')
#      12 aim2 = xa.fundinfo('110020')
#      13 aim3 = xa.fundinfo('000008')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xalpha/info.py in __init__(self, code, round_label, dividend_label, fetch, save, path, form)
#     329             form=form,
#     330             round_label=label,
# --> 331             dividend_label=dividend_label,
#     332         )
#     333
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xalpha/info.py in __init__(self, code, fetch, save, path, form, round_label, dividend_label, value_label)
#     130         self.zhesuandate = []
#     131         if fetch is False:
# --> 132             self._basic_init()  # update self. name rate and price table
#     133         else:
#     134             try:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xalpha/info.py in _basic_init(self)
#     342
#     343     def _basic_init(self):
# --> 344         self._page = _download(self._url)
#     345         if self._page.text[:800].find("Data_millionCopiesIncome") >= 0:
#     346             raise FundTypeError("This code seems to be a mfund, use mfundinfo instead")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xalpha/info.py in _download(url, tries)
#      45         except connection_errors as e:
#      46             if count == tries - 1:
# ---> 47                 raise e
#      48     return page
#      49
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xalpha/info.py in _download(url, tries)
#      41     for count in range(tries):
#      42         try:
# ---> 43             page = rq.get(url)
#      44             break
#      45         except connection_errors as e:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='fund.eastmoney.com', port=80): Max retries exceeded with url: /pingzhongdata/519152.js (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x125930198>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
#调整现金流表
dingtou1.status.set_index('date',inplace=True)
dingtou2.status.set_index('date',inplace=True)
dingtou3.status.set_index('date',inplace=True)
dingtou4.status.set_index('date',inplace=True)
dingtou5.status.set_index('date',inplace=True)

status = pd.concat([dingtou1.status,dingtou2.status,dingtou3.status,dingtou4.status,dingtou5.status],axis=1)

status
# Out:
#             519152       110020    000008    050025      000834
# date
# 2018-03-23     NaN   400.000000  800.0000  400.0000  400.000000
# 2018-03-26     NaN   400.000000       NaN       NaN         NaN
# 2018-03-27     NaN          NaN       NaN       NaN  400.000000
# 2018-03-30     NaN          NaN   -0.0025       NaN         NaN
# 2018-04-02     NaN          NaN       NaN  400.0000  400.000000
# 2018-04-16     NaN          NaN       NaN       NaN   -0.001667
# 2018-04-17     NaN   400.000000       NaN   -0.0025         NaN
# 2018-04-18     NaN          NaN       NaN       NaN   -0.002500
# 2018-04-23     NaN          NaN  400.0000       NaN         NaN
# 2018-04-25     NaN          NaN       NaN       NaN  400.000000
# 2018-05-04     NaN          NaN       NaN       NaN   -0.002500
# 2018-05-09     NaN          NaN       NaN       NaN   -0.005000
# 2018-05-10     NaN          NaN       NaN   -0.0050         NaN
# 2018-05-21     NaN          NaN   -0.0025       NaN         NaN
# 2018-05-30     NaN          NaN  800.0000       NaN         NaN
# 2018-06-15     NaN          NaN  400.0000       NaN         NaN
# 2018-06-19     NaN   400.000000  400.0000       NaN         NaN
# 2018-06-21     NaN   400.000000       NaN       NaN         NaN
# 2018-06-25   400.0          NaN       NaN       NaN         NaN
# 2018-09-25   800.0          NaN       NaN       NaN         NaN
# 2018-12-12   800.0          NaN       NaN       NaN         NaN
# 2018-12-21     NaN          NaN       NaN       NaN  400.000000
# 2018-12-24     NaN          NaN       NaN  400.0000  400.000000
# 2018-12-26     NaN          NaN       NaN       NaN   -0.002500
# 2019-01-02     NaN          NaN       NaN       NaN   -0.005000
# 2019-01-04     NaN          NaN       NaN   -0.0050         NaN
# 2019-02-25     NaN    -0.001000       NaN       NaN         NaN
# 2019-03-05     NaN    -0.001250       NaN       NaN         NaN
# 2019-04-01     NaN    -0.001667       NaN       NaN         NaN
# 2019-04-04     NaN    -0.002500       NaN       NaN         NaN
# 2019-04-16     NaN    -0.005000       NaN       NaN         NaN
# 2019-05-06     NaN  1200.000000       NaN       NaN         NaN
# 2019-05-09     NaN   400.000000       NaN       NaN         NaN
# 2019-06-20     NaN    -0.001250       NaN       NaN         NaN
# 2019-07-01     NaN    -0.001667       NaN       NaN         NaN
# 2019-08-06     NaN   400.000000       NaN       NaN         NaN
# 2019-08-23     NaN    -0.001667       NaN       NaN         NaN
# 2019-09-04     NaN    -0.002500       NaN       NaN         NaN
# 2019-09-09     NaN    -0.005000       NaN       NaN         NaN
# 2020-02-03     NaN   800.000000       NaN       NaN         NaN
# 2020-02-06     NaN    -0.002500       NaN       NaN         NaN
# 2020-02-12     NaN    -0.005000       NaN       NaN         NaN
# 2020-02-25     NaN          NaN   -0.0010       NaN         NaN
# 2020-02-28     NaN          NaN  400.0000       NaN         NaN

# %%
status = status.reset_index()

#status.fillna(0)

#status.to_csv('./status.csv')

status
# Out:
#          date  519152       110020    000008    050025      000834
# 0  2018-03-23     NaN   400.000000  800.0000  400.0000  400.000000
# 1  2018-03-26     NaN   400.000000       NaN       NaN         NaN
# 2  2018-03-27     NaN          NaN       NaN       NaN  400.000000
# 3  2018-03-30     NaN          NaN   -0.0025       NaN         NaN
# 4  2018-04-02     NaN          NaN       NaN  400.0000  400.000000
# 5  2018-04-16     NaN          NaN       NaN       NaN   -0.001667
# 6  2018-04-17     NaN   400.000000       NaN   -0.0025         NaN
# 7  2018-04-18     NaN          NaN       NaN       NaN   -0.002500
# 8  2018-04-23     NaN          NaN  400.0000       NaN         NaN
# 9  2018-04-25     NaN          NaN       NaN       NaN  400.000000
# 10 2018-05-04     NaN          NaN       NaN       NaN   -0.002500
# 11 2018-05-09     NaN          NaN       NaN       NaN   -0.005000
# 12 2018-05-10     NaN          NaN       NaN   -0.0050         NaN
# 13 2018-05-21     NaN          NaN   -0.0025       NaN         NaN
# 14 2018-05-30     NaN          NaN  800.0000       NaN         NaN
# 15 2018-06-15     NaN          NaN  400.0000       NaN         NaN
# 16 2018-06-19     NaN   400.000000  400.0000       NaN         NaN
# 17 2018-06-21     NaN   400.000000       NaN       NaN         NaN
# 18 2018-06-25   400.0          NaN       NaN       NaN         NaN
# 19 2018-09-25   800.0          NaN       NaN       NaN         NaN
# 20 2018-12-12   800.0          NaN       NaN       NaN         NaN
# 21 2018-12-21     NaN          NaN       NaN       NaN  400.000000
# 22 2018-12-24     NaN          NaN       NaN  400.0000  400.000000
# 23 2018-12-26     NaN          NaN       NaN       NaN   -0.002500
# 24 2019-01-02     NaN          NaN       NaN       NaN   -0.005000
# 25 2019-01-04     NaN          NaN       NaN   -0.0050         NaN
# 26 2019-02-25     NaN    -0.001000       NaN       NaN         NaN
# 27 2019-03-05     NaN    -0.001250       NaN       NaN         NaN
# 28 2019-04-01     NaN    -0.001667       NaN       NaN         NaN
# 29 2019-04-04     NaN    -0.002500       NaN       NaN         NaN
# 30 2019-04-16     NaN    -0.005000       NaN       NaN         NaN
# 31 2019-05-06     NaN  1200.000000       NaN       NaN         NaN
# 32 2019-05-09     NaN   400.000000       NaN       NaN         NaN
# 33 2019-06-20     NaN    -0.001250       NaN       NaN         NaN
# 34 2019-07-01     NaN    -0.001667       NaN       NaN         NaN
# 35 2019-08-06     NaN   400.000000       NaN       NaN         NaN
# 36 2019-08-23     NaN    -0.001667       NaN       NaN         NaN
# 37 2019-09-04     NaN    -0.002500       NaN       NaN         NaN
# 38 2019-09-09     NaN    -0.005000       NaN       NaN         NaN
# 39 2020-02-03     NaN   800.000000       NaN       NaN         NaN
# 40 2020-02-06     NaN    -0.002500       NaN       NaN         NaN
# 41 2020-02-12     NaN    -0.005000       NaN       NaN         NaN
# 42 2020-02-25     NaN          NaN   -0.0010       NaN         NaN
# 43 2020-02-28     NaN          NaN  400.0000       NaN         NaN

# %%
#调整现金流表
#status = pd.concat([dingtou1.status,dingtou2.status,dingtou3.status,dingtou4.status,dingtou5.status],axis=1)

#status.drop(columns = 'date',inplace = True)

#status['date'] = data_range

#status = status[['date','519152','110020','000008','050025','000834']]

#status

# %%
#创建基金定投组合
mul = xa.mul(status=status)

mul.combsummary()
# Out:
# ---------------------------------------------------------------------------
# TradeBehaviorError                        Traceback (most recent call last)
# <ipython-input-11-31cdacb9d67e> in <module>
#       1 #创建基金定投组合
# ----> 2 mul = xa.mul(status=status)
#       3
#       4 mul.combsummary()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xalpha/multiple.py in __init__(self, status, property, fetch, save, path, form, *fundtradeobj)
#      72                                 form=form,
#      73                             ),
# ---> 74                             status,
#      75                         )
#      76                     )
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xalpha/trade.py in __init__(self, infoobj, status)
#     170         self.remtable = pd.DataFrame([], columns=["date", "rem"])
#     171         self.status = status.loc[:, ["date", code]]
# --> 172         self._arrange()
#     173
#     174     def _arrange(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xalpha/trade.py in _arrange(self)
#     180                     break
#     181                 else:
# --> 182                     raise e
#     183
#     184     def _addrow(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xalpha/trade.py in _arrange(self)
#     175         while 1:
#     176             try:
# --> 177                 self._addrow()
#     178             except Exception as e:
#     179                 if e.args[0] == "no other info to be add into cashflow table":
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/xalpha/trade.py in _addrow(self)
#     205                 rem = rm.buy([], share, rdate)
#     206             else:
# --> 207                 raise TradeBehaviorError("You cannot sell first when you never buy")
#     208         elif len(self.cftable) > 0:
#     209             recorddate = list(self.status.date)
#
# TradeBehaviorError: You cannot sell first when you never buy

# %%
mul.xirrrate()

# %%
mul.v_positions_history()

# %%
mul.v_positions()
